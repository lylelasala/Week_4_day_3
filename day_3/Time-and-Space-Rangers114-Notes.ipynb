# %% [markdown]
# # Time/Space Complexity - Intro to Data Structures (User Defined)
#
# ### Topics to discuss today:
#
# <ul>
#     <li>Time and Space Complexity - What is it/How do we measure it</li>
#     <li>Asymptotic Analysis</li>
#     <li><strong>Data Structures</strong></li>
#     <li>Some of the popular sorting algorithms</li>
# </ul>
#
# ### Data Structures to discuss:
# - Arrays
# - Stacks
# - Queues
# - Linked Lists
#     - Singly Linked Lists
#     - Traversing A Linked List
#     - Finding a node in a linked list
#     - Adding to a linked list

# %% [markdown]
# ## Time and Space Complexity
#
# #### What is it?
#
# Time and space complexity is the measure of how much time a given action(function) will take to solve a problem. In the same fashion, we determine how much a given data structure will need in terms of memory allocation. A problem can have multiple solutions and finding the optimal solution for the problem needs to be analyzed in time and space.
#
# #### How do we measure Time and Space Complexity?
#
# In order to measure time and space complexity we use Asymptotic analysis. The reason for this is because we need a way to measure different algorithms (functions) based on the size of their inputs in a mathmatical way. For example, we could have a function that is computed as f(n) and another that is g(n^2). All things around the function staying constant, the only thing that changes is the size of the input. Below is the chart that shows the different Asymptotic analysis formats.

# %% [markdown]
# <table style="text-align:center;" class="table table-bordered">
# <tbody><tr>
# <td>constant</td>
# <td>−</td>
# <td>Ο(1)</td>
# </tr>
# <tr>
# <td>logarithmic</td>
# <td>−</td>
# <td>Ο(log n)</td>
# </tr>
# <tr>
# <td>linear</td>
# <td>−</td>
# <td>Ο(n)</td>
# </tr>
# <tr>
# <td>Linear Logarithmic</td>
# <td>−</td>
# <td>Ο(n log n)</td>
# </tr>
# <tr>
# <td>quadratic</td>
# <td>−</td>
# <td>Ο(n<sup>2</sup>)</td>
# </tr>
# <tr>
# <td>cubic</td>
# <td>−</td>
# <td>Ο(n<sup>3</sup>)</td>
# </tr>
# <tr>
# <td>polynomial</td>
# <td>−</td>
# <td>n<sup>Ο(1)</sup></td>
# </tr>
# <tr>
# <td>exponential</td>
# <td>−</td>
# <td>2<sup>Ο(n)</sup></td>
# </tr>
# </tbody></table>

# %%
#constant time AND constant space O(1)
def add_nums(num1, num2):
    return num1 + num2
#.append()

#O(log n) Logarithmic
#Binary Search
def binary_search(array, target):
    left = 0
    right = len(array) - 1
    while left <= right:
        middle = (left+right)//2
        potential_match = array[middle]
        if target == potential_match:
            return f"The index is {middle}"
        elif target < potential_match:
            right = middle - 1
        else: 
            left = middle + 1
    return -1

# O(n) Linear
# time increases with the number of inputs
arr = [1, 2, 3, 4, 5]
def print_num(arr):
    for num in arr:
        print(num)
        
def print_num_while(arr):
    index = 0
    while index < len(arr):
        print(arr[index])
        index += 1
        
print(print_num_while(arr))
# .count()
# .index() 
#max() specifically with iterable
#min() specifically with iterable
#sum() on an iterable

#O (n log n) Linear Logarithmic
#Merge Sort
#.sort()
#sorted()

#Quadratic O(n^2)
#lucky number: find the number that occurs as many times as its value, if there is
# more than one, return the largest of the lucky numbers
arr = [1, 2, 2, 3, 3, 3, 4]
def lucky_nums(arr):
    count_arr = []
    for num in arr: #linear for loop
        if num == arr.count(num): # nested linear builtin in method
            count_arr.append(num) 
    return count_arr

arr2 = [10,2,5,3, 6, 7, 1]
def number2(arr):
    for i in arr: #linear for loop
        if i*2 in arr: # nested linear membership check in a list
            return True
    else:
        return False
print(number2(arr))

def print_lotsonums(arr1, arr2):
    for x in arr1: #linear for loop
        print(x)
        for y in arr2: # nested linear for loop
            print(y)
# print_lotsonums(arr, arr2)


#Cubic O(n^3)
#any triply nested linear equation
#foor loops in for loops
#while loops in for loops
# several nested linear built in methods
def print_nums3(arr1, arr2, arr3):
    for num1 in arr1:
        for num2 in arr2:
            my_arr.append(num1.count(4))
            for num3 in arr3:
                print(num1 + num2 + num3)
# Out:
# True

# %% [markdown]
# ## Arrays

# %% [markdown]
# In python we benefit from the dynamic array which means the block of memory will expand as needed for the given input to the array. In traditional arrays (depending on the type of operating system) we will usually store our inputs in 4 or 8 consecutive blocks of memory. Below is a diagram of how that looks under the hood:
#
# <img src="http://www.mathcs.emory.edu/~cheung/Courses/170/Syllabus/09/FIGS/array02x.gif" style="height:250px; width:350px;">

# %% [markdown]
# ## Which in python looks like this:

# %%
#indexing an array (list)
#Constant and Space
#arr[i]
my_list = [1, 2, 3, 4, 5]
my_num = my_list[3]

#searching through an array
# membership check
# Linear O(n) time and Constant Space 0(1)
if 6 in my_list:
    print("its here")
else:
    print("oh no")
    
#copying an array
#linear TIme O(n) Space 
my_list_copy = my_list[:]
empty_list = []
for num in my_list:
    empty_list.append(num)
    
# setting an index
# constant time 0(1) and constant space 0(1)
my_list[3] = 7
print(my_list)
# Out:
# oh no
# [1, 2, 3, 7, 5]

# %% [markdown]
# ### Let's take a look at some of the time and space analysis of arrays

# %%
#see above

# %% [markdown]
# ## Stacks and Queues
#
# ** Stacks ** as the name suggests is a data structure that allows for data to follow the Last In First Out priciple(LIFO). Think of a stack of pancakes for example. To get the first pancake you would  start with the top and go down.
#
# ##### Searching through a stack will be Linear Time O(n) - Constant Space O(1)
# ##### Selecting the last item will be done in Constant Time O(1) - Constant Space O(1)
# ##### Adding to the stack should take Constant Time O(1) - Constant Space O(1)
#
# ** Queues ** are similar but in this case follow the First In First Out principle(FIFO). Think of this as a line in a black friday sale. The first person camped out for the big screen tv is the first to get it.
#
# ##### Searching through a queue will be Linear Time O(n) - Constant Space O(1)
# ##### Selecting the first item will be done in Constant Time O(1) - Constant Space O(1)
# ##### Adding to the queue should take Constant Time O(1) - Constant Space O(1)

# %%
# stacks
stack = ['pancake1']
print(stack)
stack.append("pancake2")
print(stack)
stack.append('pancake3')
print(stack)
stack.append('pancake4')
print(stack)
print(stack.pop(1))
print(stack)
print(stack.pop())
print(stack)
# Out:
# ['pancake1']
# ['pancake1', 'pancake2']
# ['pancake1', 'pancake2', 'pancake3']
# ['pancake1', 'pancake2', 'pancake3', 'pancake4']
# pancake2
# ['pancake1', 'pancake3', 'pancake4']
# pancake4
# ['pancake1', 'pancake3']

# %%
from collections import deque
#stack
# first in last out
# last in first out

stack = deque()
print(stack)
stack.appendleft("pancake1")
print(stack)
stack.appendleft("pancake2")
print(stack)
stack.appendleft("pancake3")
print(stack)
stack.appendleft("pancake4")
print(stack)
print(stack.popleft())
print(stack)
print(stack.popleft())
print(stack)
# Out:
# deque([])
# deque(['pancake1'])
# deque(['pancake2', 'pancake1'])
# deque(['pancake3', 'pancake2', 'pancake1'])
# deque(['pancake4', 'pancake3', 'pancake2', 'pancake1'])
# pancake4
# deque(['pancake3', 'pancake2', 'pancake1'])
# pancake3
# deque(['pancake2', 'pancake1'])

# %%
from collections import deque
# Queue
# first shopper in, first shopper out
queue = deque()
print(queue)
queue.appendleft("shopper1")
print (queue)
queue.appendleft("shopper2")
print (queue)
queue.appendleft("shopper3")
print (queue)
queue.appendleft("shopper4")
print (queue)
print(queue.pop())
print (queue)
print(queue.pop())
print (queue)
queue.appendleft("shopper5")
print (queue)
queue.appendleft("shopper6")
print (queue)
# Out:
# deque([])
# deque(['shopper1'])
# deque(['shopper2', 'shopper1'])
# deque(['shopper3', 'shopper2', 'shopper1'])
# deque(['shopper4', 'shopper3', 'shopper2', 'shopper1'])
# shopper1
# deque(['shopper4', 'shopper3', 'shopper2'])
# shopper2
# deque(['shopper4', 'shopper3'])
# deque(['shopper5', 'shopper4', 'shopper3'])
# deque(['shopper6', 'shopper5', 'shopper4', 'shopper3'])

# %% [markdown]
# # Sum of Parts Time Compelxity Exercise

# %%
#sum of parts
https://www.codewars.com/kata/5ce399e0047a45001c853c2b

# %%
# definitely study up on this ahahahahahhahahah
from collections import deque

def parts_sums(ls):
    sum_dict = {}
    dict_counter = 0
    ls = deque()
    sum_list = []
    while ls:
        sum_dict[dict_counter] = sum(ls)
        ls.popleft()
        dict_counter += 1

    sum_dict[dict_counter] = sum(ls)
    for value in sum_dict.values():
        sum_list.append(value)
    return sum_list

# %%
def parts_sums(ls):
    # start working list as BACKWARD version
    arr = ls[::-1]
    ret_list = []
    current_sum = sum(arr)
    

    #iterate through list backward
    for i in range(0,len(arr)):
    
        ret_list.append(current_sum)
        current_sum -= arr.pop()
        
    ret_list.append(0)
    return ret_list

# %%
def parts_sums(ls):
    result = [sum(ls)]
    for item in ls:
        result.append(result[-1]-item)
    return result

or my hacky solution:
def parts_sums(ls):
    result = (len(ls) + 1) * [0]
    for i in range(len(ls)-1, -1, -1):
        result[i] = ls[i] + result[i+1]
    return result

# %% [markdown]
# ## Linked List (Data Structure)
#
# A linked list is created by using the node class. We create a Node object and create another class to use this node object. We pass the appropriate values thorugh the node object to point the to the next data elements.
#
# There are some advantages and disadvantages with this data structure. **Advantages** Linked Lists can save memory because they can be flexibile with memory management which saves memory. **Disadvantages** Finding or adding to the list requires traversing the entire list.

# %%
# #Implementation of a linked list

# #2 components to the structure
# #node class - value and next attributes 
# #linked list class - how we add, to and traverse the list

# #node class
# class Node():
#     def __init__(self, value):
#         self.value = value
#         self.next = None
        
# #Linked list class
# class LinkedList():
#     def __init__(self):
#         self.head = None
        
#         #pushOn - place an item at the head of the list == the beginning
#         def pushOn(self, new_value):
#             new_node = Node(new_value)
#             new_node.next = self.head
#             self.head = new_node
            
#         #insertAfter - place a node after another in the linked list
#         def insertAfter(self, prev_node, new_value):
# #            #check if the previous node exists
#             if prev_node is None:
#                 print("The given node must not be empty")
#                 return
#             #if the prev_node is not empty, we create a new node
#             new_node = Node(new_value)
            
#             #update the new node's next attrribute (pointer) to the prev_nodes next
#             new_node.next = prev_node.next
            
#             #update prev_nodes next to our new_node
#             prev_node.next = new_node
            
#         #append(add) to the END of the linked list
#         def append(self, new_value):
#             #create a new node object -- new_node = Node(value)
#             new_node = Node(new_value)
            
#             #check if list is empty
#             # if it os, make this new node the head(beginning of the list)
#             if self.head is None:
#                 self.head = new_node
                
#         #traverse - move through the linked list
#         def traverse(self):
#             temp = self.head
            
#             #while temp is NOT NONE ---> keep moving through the list until it is none
#             while temp:
#                 print(temp.value)
#                 temp = temp.next
#             print("end of list")
            
    
#     double check

# %%
# #Implementation of a linked list

# #2 componenets to the structure
# #Node Class - value and next attributes
# #Linked List class - how we add, to and traverse the list

# #Node class
# class Node():
#     def __init__(self, value):
#         self.value = value
#         self.next = None
        
# #Linked List Class
# class LinkedList():
#     def __init__(self):
#         self.head = None
        
#     #pushOn - place an item at the head of the list -- the beginning
#     def pushOn(self, new_value):
#         new_node = Node(new_value)
#         new_node.next = self.head
#         self.head = new_node
        
#     #insertAfter - place a node after another in the linked list
#     def insertAfter(self, prev_node, new_value):
#         #check if the previous node exists
#         if prev_node is None:
#             print("The given node must not be empty")
#             return
#         #if the prev_node is not empty, we create a new node
#         new_node = Node(new_value)
        
#         #update the new node's next attribute(pointer) to point to the prev_nodes next
#         new_node.next = prev_node.next
        
#         #update prev_nodes next to our new_node
#         prev_node.next = new_node
        
#     #append(add) to the the END of the linked list
#     def append(self, new_value):
#         #create a new node object -- new_node = Node(value)
#         new_node = Node(new_value)
        
#         #check if list is empty
#         # if it is, make this new node the head(beginning of the list)
#         if self.head is None:
#             self.head = new_node
            
#         #if not empty, traverse the list and append it to the end
#         last = self.head #node obect last.value and last.next
        
#         #change the current last to the next node and continously check if last.next is None
#         while last.next:
#             last = last.next
            
#         #change the current last node next value(which is currently none) to the new_node
#         last.next = new_node
        
#     #traverse - move through the linked list
#     def traverse(self):
#         temp = self.head
        
#         #while temp is NOT NONE --> keep moving through the list until it is none
#         while temp:
#             print(temp.value)
#             temp = temp.next
#         print("end of list")

# %%
#Implementation of a linked list

#2 componenets to the structure
#Node Class - value and next attributes
#Linked List class - how we add, to and traverse the list

#Node class
class Node():
    def __init__(self, value):
        self.value = value
        self.next = None
        
#Linked List Class
class LinkedList():
    def __init__(self):
        self.head = None
        self.length = 0
        
    #pushOn - place an item at the head of the list -- the beginning
    def pushOn(self, new_value):
        new_node = Node(new_value)
        new_node.next = self.head
        self.head = new_node
        self.length += 1
        
    #insertAfter - place a node after another in the linked list
    def insertAfter(self, prev_node, new_value):
        #check if the previous node exists
        if prev_node is None:
            print("The given node must not be empty")
            return
        #if the prev_node is not empty, we create a new node
        new_node = Node(new_value)
        
        #update the new node's next attribute(pointer) to point to the prev_nodes next
        new_node.next = prev_node.next
        
        #update prev_nodes next to our new_node
        prev_node.next = new_node

#     def insertAfter(self, position, new_value):

#         new_node = Node(new_value)
#         slow = self.head
#         fast = self.head.next

#         for i in range(position-1):
#             slow = slow.next
#             fast = fast.next.next

#         new_node.next = slow.next
#         slow.next = new_node
#         self.length += 1
        
    #append(add) to the the END of the linked list
    def append(self, new_value):
        #create a new node object -- new_node = Node(value)
        new_node = Node(new_value)
        
        
        #check if list is empty
        # if it is, make this new node the head(beginning of the list)
        if self.head is None:
            self.head = new_node
            
        #if not empty, traverse the list and append it to the end
        last = self.head #node obect last.value and last.next
        
        #change the current last to the next node and continously check if last.next is None
        while last.next:
            last = last.next
            
        #change the current last node next value(which is currently none) to the new_node
        self.length += 1
        last.next = new_node
        
    def remove_node(self, r_value):
        temp = self.head
        
        while temp.value != r_value:
            prev = temp
            temp = temp.next
        prev.next = temp.next
        
        
        
        
        
        
        
    #traverse - move through the linked list
    def traverse(self):
        temp = self.head
        
        #while temp is NOT NONE --> keep moving through the list until it is none
        while temp:
            print(temp.value)
            temp = temp.next
        print("end of list")

# %%
weekdays_list = LinkedList()
weekdays_list.pushOn("Monday")
# weekdays_list.traverse()
# weekdays_list.head .value
weekdays_list.append("Wednesday")

weekdays_list.insertAfter(weekdays_list.head, "Tuesday")
# weekdays_list.traverse()
weekdays_list.insertAfter(weekdays_list.head.next.next, "Thursday")
weekdays_list.traverse()
weekdays_list.append("Friday")
# weekdays_list.traverse()
weekdays_list.append("Saturday")
# weekdays_list.traverse()
weekdays_list.pushOn("Sunday")
# weekdays_list.traverse()
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# end of list

# %%
## W4 D3 -- Homework: Codewars

# %%
# For homework please revisit 3 codewars problems and refactor your solution to improve their time complexity. 

# Also read through the following data structures for some additional understanding!

# Once youve finished drop one of the problems in the slack.

# %%
# C.Wars
# Normally we have firstname, middle and the last name but there may be more than one word in a name like a South Indian one.

# Similar to those kinda names we need to initialize the names.

# See the pattern below:

# initials('code wars') => returns C.Wars 
# initials('Barack Hussain obama') => returns B.H.Obama 

# Complete the function initials.

# Names are separated by exactly one space in the input, without leading or trailing spaces. Names will always be lowercase, except optionally their first letter.

# %%
# Original Time Complexity
def initials(name):
    name_list = name.split()
    full_name = ""
    for word in name_list:
        if word != name_list[-1]:
            full_name += word[0].title() + '.'
        else:
            full_name += word.title()
    return full_name

# %%
#Refactored
def initials(name):
    name_list = name.split()
    first_initials = [word[0].title() for word in name_list[:-1]]
    last_name = name_list[-1].title()
    return '.'.join(first_initials + [last_name])

# %%
## Sum of Parts
# Let us consider this example (array written in general format):

# ls = [0, 1, 3, 6, 10]

# Its following parts:

# ls = [0, 1, 3, 6, 10]
# ls = [1, 3, 6, 10]
# ls = [3, 6, 10]
# ls = [6, 10]
# ls = [10]
# ls = []

# The corresponding sums are (put together in a list): [20, 20, 19, 16, 10, 0]

# The function parts_sums (or its variants in other languages) will take as parameter a list ls and return a list of the sums of its parts as defined above.

# Other Examples:
# ls = [1, 2, 3, 4, 5, 6] 
# parts_sums(ls) -> [21, 20, 18, 15, 11, 6, 0]

# ls = [744125, 935, 407, 454, 430, 90, 144, 6710213, 889, 810, 2579358]
# parts_sums(ls) -> [10037855, 9293730, 9292795, 9292388, 9291934, 9291504, 9291414, 9291270, 2581057, 2580168, 2579358, 0]

# %%
# Original Time Complexcity - In Class
def parts_sums(ls):
    arr = ls[::-1]
    ret_list = []
    current_sum = sum(arr)
    
    for i in range(0,len(arr)):
    
        ret_list.append(current_sum)
        current_sum -= arr.pop()
        
    ret_list.append(0)
    return ret_list

# %%
#Refactored
def parts_sums(ls):
    total_sum = sum(ls)
    ret_list = [total_sum]
    
    for num in ls:
        total_sum -= num
        ret_list.append(total_sum)
        
    return ret_list

# %%
## Multiply 
# This code does not execute properly. Try to figure out why.
# def multiply(a, b):
#     a * b

# %%
# Original Time Complexcity 
def multiply(a, b):
    result = 0
    
    while a > 0:
        if a % 2 == 1:
            result += b
        a //= 2
        b *= 2
        
    return result

# %%
#Refactored
def multiply(a, b):
    result = 0
    shift = 0
    
    while a > 0:
        if a & 1:
            result += b << shift
        a >>= 1
        shift += 1
        
    return result
